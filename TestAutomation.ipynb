# %%
#Change values as needed. Trials is number of trials, initialVal is initial value of variable studied, and stepVal is how much you
#would like to increase it by every trial. varStudied is the name of the variable you are changing.
trials=3;
initialVal=1;
stepVal=3;
varStudied="temp"
#Change value of variable that you would like to change equal to x in the location of the simulation code. Ex: Changing temp and
#kt=_ becomes kt=x

#Run the first for-loop to get a strinking box
#Run the second for-loop to get a constant sized box

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from flowermd.base import Pack, Simulation
from flowermd.library import PPS, BeadSpring
from flowermd.utils import get_target_box_mass_density
import unyt as u

# %%
x=initialVal;
for i in range(trials):
    pps_mol = PPS(num_mols=5, lengths=20)
    pps_mol.coarse_grain(beads={"A": "c1ccc(S)cc1"})
    ff = BeadSpring(
    r_cut=2.5,
    beads={
        "A": dict(epsilon=1, sigma=0.2),
    },
    bonds={
        "A-A": dict(r0=0.64, k=500),
    },
    angles={"A-A-A": dict(t0=2.8, k=50)},
)
    ff.hoomd_forces
    cg_system = Pack(molecules=pps_mol, density=1, edge=.2, overlap=.2,packing_expand_factor=5)
    gsd_path=varStudied+str(x)+'.gsd'
    cg_sim = Simulation(
    initial_state=cg_system.hoomd_snapshot,
    forcefield=ff.hoomd_forces,
    gsd_write_freq=int(2e5/10),
    gsd_file_name=gsd_path,
    reference_values={"length": 1*u.nm, "mass": 1*u.Unit("amu"), "energy":1*u.Unit("kJ/mol")}
)
    target_box = get_target_box_mass_density(density=0.5*u.Unit("g/cm**3"), mass=cg_system.mass.to("g"))
    cg_sim.run_update_volume(n_steps=4e5, kT=3, tau_kt=1.0, final_box_lengths=target_box, period=100)
    cg_sim.flush_writers()
    x=x+stepVal;
# Out:
# Initializing simulation state from a gsd.hoomd.Frame.
# Step 10500 of 400000; TPS: 18141.86; ETA: 0.4 minutes
# Step 21000 of 400000; TPS: 24981.86; ETA: 0.3 minutes
# Step 31500 of 400000; TPS: 28217.41; ETA: 0.2 minutes
# Step 42000 of 400000; TPS: 30031.47; ETA: 0.2 minutes
# Step 52500 of 400000; TPS: 30797.17; ETA: 0.2 minutes
# Step 63000 of 400000; TPS: 31580.64; ETA: 0.2 minutes
# Step 73500 of 400000; TPS: 32137.72; ETA: 0.2 minutes
# Step 84000 of 400000; TPS: 32494.46; ETA: 0.2 minutes
# Step 94500 of 400000; TPS: 32927.78; ETA: 0.2 minutes
# Step 105000 of 400000; TPS: 33061.12; ETA: 0.1 minutes
# Step 115500 of 400000; TPS: 33197.83; ETA: 0.1 minutes
# Step 126000 of 400000; TPS: 32976.39; ETA: 0.1 minutes
# Step 136500 of 400000; TPS: 32854.67; ETA: 0.1 minutes
# Step 147000 of 400000; TPS: 32584.93; ETA: 0.1 minutes
# Step 157500 of 400000; TPS: 32296.86; ETA: 0.1 minutes
# Step 168000 of 400000; TPS: 31953.39; ETA: 0.1 minutes
# Step 178500 of 400000; TPS: 31540.7; ETA: 0.1 minutes
# Step 189000 of 400000; TPS: 28747.47; ETA: 0.1 minutes
# Step 199500 of 400000; TPS: 27888.14; ETA: 0.1 minutes
# Step 210000 of 400000; TPS: 27623.76; ETA: 0.1 minutes
# Step 220500 of 400000; TPS: 27127.57; ETA: 0.1 minutes
# Step 231000 of 400000; TPS: 26842.19; ETA: 0.1 minutes
# Step 241500 of 400000; TPS: 26446.27; ETA: 0.1 minutes
# Step 252000 of 400000; TPS: 25976.77; ETA: 0.1 minutes
# Step 262500 of 400000; TPS: 25419.52; ETA: 0.1 minutes
# Step 273000 of 400000; TPS: 24818.67; ETA: 0.1 minutes
# Step 283500 of 400000; TPS: 24154.23; ETA: 0.1 minutes
# Step 294000 of 400000; TPS: 23557.83; ETA: 0.1 minutes
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 26
#      18     cg_sim = Simulation(
#      19     initial_state=cg_system.hoomd_snapshot,
#      20     forcefield=ff.hoomd_forces,
#    (...)
#      23     reference_values={"length": 1*u.nm, "mass": 1*u.Unit("amu"), "energy":1*u.Unit("kJ/mol")}
#      24 )
#      25     target_box = get_target_box_mass_density(density=0.5*u.Unit("g/cm**3"), mass=cg_system.mass.to("g"))
# ---> 26     cg_sim.run_update_volume(n_steps=4e5, kT=temp, tau_kt=1.0, final_box_lengths=target_box, period=100)
#      27     cg_sim.flush_writers()
#      28     temp=temp+1;
#
# File ~/Desktop/repos/flowerMD/flowermd/base/simulation.py:739, in Simulation.run_update_volume(self, final_box_lengths, n_steps, period, kT, tau_kt, thermalize_particles, write_at_start)
#     734 std_out_logger_printer = hoomd.update.CustomUpdater(
#     735     trigger=hoomd.trigger.Periodic(self._std_out_freq),
#     736     action=std_out_logger,
#     737 )
#     738 self.operations.updaters.append(std_out_logger_printer)
# --> 739 self.run(steps=n_steps + 1, write_at_start=write_at_start)
#     740 self.operations.updaters.remove(std_out_logger_printer)
#     741 self.operations.updaters.remove(box_resizer)
#
# File ~/miniforge3/envs/flowermd/lib/python3.11/site-packages/hoomd/simulation.py:562, in Simulation.run(self, steps, write_at_start)
#     558 if steps_int < 0 or steps_int > TIMESTEP_MAX - 1:
#     559     raise ValueError(f"steps must be in the range [0, "
#     560                      f"{TIMESTEP_MAX-1}]")
# --> 562 self._cpp_sys.run(steps_int, write_at_start)
#
# RuntimeError: nlist: Simulation box is too small, the neighbor list is searching beyond the  minimum image: rmax=2.9
# nearest_plane_distance.x=5.79889
# nearest_plane_distance.y=5.79889
# nearest_plane_distance.z=5.79889

# %%
x=initialVal;
for i in range(trials):
    pps_mol = PPS(num_mols=5, lengths=20)
    pps_mol.coarse_grain(beads={"A": "c1ccc(S)cc1"})
    ff = BeadSpring(
    r_cut=2.5,
    beads={
        "A": dict(epsilon=1, sigma=0.2),
    },
    bonds={
        "A-A": dict(r0=0.64, k=500),
    },
    angles={"A-A-A": dict(t0=2.8, k=50)},
)
    ff.hoomd_forces
    cg_system = Pack(molecules=pps_mol, density=1, edge=.2, overlap=.2,packing_expand_factor=5)
    gsd_path=varStudied+str(x)+'.gsd'
    cg_sim = Simulation(
    initial_state=cg_system.hoomd_snapshot,
    forcefield=ff.hoomd_forces,
    gsd_write_freq=int(2e5/10),
    gsd_file_name=gsd_path,
    reference_values={"length": 1*u.nm, "mass": 1*u.Unit("amu"), "energy":1*u.Unit("kJ/mol")}
)
    cg_sim.run_NVT(n_steps=4e5, kT=x, tau_kt=1.0)
    cg_sim.flush_writers()
    x=x+stepVal;
# Out:
# Initializing simulation state from a gsd.hoomd.Frame.
# Step 10500 of 400000; TPS: 19475.17; ETA: 0.3 minutes
# Step 21000 of 400000; TPS: 26293.81; ETA: 0.2 minutes
# Step 31500 of 400000; TPS: 29543.07; ETA: 0.2 minutes
# Step 42000 of 400000; TPS: 31541.33; ETA: 0.2 minutes
# Step 52500 of 400000; TPS: 32841.03; ETA: 0.2 minutes
# Step 63000 of 400000; TPS: 33751.57; ETA: 0.2 minutes
# Step 73500 of 400000; TPS: 34454.02; ETA: 0.2 minutes
# Step 84000 of 400000; TPS: 34971.27; ETA: 0.2 minutes
# Step 94500 of 400000; TPS: 35347.28; ETA: 0.1 minutes
# Step 105000 of 400000; TPS: 35677.96; ETA: 0.1 minutes
# Step 115500 of 400000; TPS: 35975.19; ETA: 0.1 minutes
# Step 126000 of 400000; TPS: 36229.21; ETA: 0.1 minutes
# Step 136500 of 400000; TPS: 36525.9; ETA: 0.1 minutes
# Step 147000 of 400000; TPS: 36712.51; ETA: 0.1 minutes
# Step 157500 of 400000; TPS: 36830.5; ETA: 0.1 minutes
# Step 168000 of 400000; TPS: 36961.78; ETA: 0.1 minutes
# Step 178500 of 400000; TPS: 37127.24; ETA: 0.1 minutes
# Step 189000 of 400000; TPS: 37215.84; ETA: 0.1 minutes
# Step 199500 of 400000; TPS: 37307.8; ETA: 0.1 minutes
# Step 210000 of 400000; TPS: 37431.75; ETA: 0.1 minutes
# Step 220500 of 400000; TPS: 37507.44; ETA: 0.1 minutes
# Step 231000 of 400000; TPS: 37551.1; ETA: 0.1 minutes
# Step 241500 of 400000; TPS: 37633.85; ETA: 0.1 minutes
# Step 252000 of 400000; TPS: 37676.75; ETA: 0.1 minutes
# Step 262500 of 400000; TPS: 37718.11; ETA: 0.1 minutes
# Step 273000 of 400000; TPS: 37762.88; ETA: 0.1 minutes
# Step 283500 of 400000; TPS: 37800.93; ETA: 0.1 minutes
# Step 294000 of 400000; TPS: 37832.45; ETA: 0.0 minutes
# Step 304500 of 400000; TPS: 37892.33; ETA: 0.0 minutes
# Step 315000 of 400000; TPS: 37916.84; ETA: 0.0 minutes
# Step 325500 of 400000; TPS: 37954.76; ETA: 0.0 minutes
# Step 336000 of 400000; TPS: 37975.69; ETA: 0.0 minutes
# Step 346500 of 400000; TPS: 38013.09; ETA: 0.0 minutes
# Step 357000 of 400000; TPS: 38041.61; ETA: 0.0 minutes
# Step 367500 of 400000; TPS: 38073.55; ETA: 0.0 minutes
# Step 378000 of 400000; TPS: 38099.95; ETA: 0.0 minutes
# Step 388500 of 400000; TPS: 38117.45; ETA: 0.0 minutes
# Step 399000 of 400000; TPS: 38161.0; ETA: 0.0 minutes
# Initializing simulation state from a gsd.hoomd.Frame.
# Step 10500 of 400000; TPS: 18971.77; ETA: 0.3 minutes
# Step 21000 of 400000; TPS: 25679.09; ETA: 0.2 minutes
# Step 31500 of 400000; TPS: 28992.02; ETA: 0.2 minutes
# Step 42000 of 400000; TPS: 31016.89; ETA: 0.2 minutes
# Step 52500 of 400000; TPS: 32341.71; ETA: 0.2 minutes
# Step 63000 of 400000; TPS: 33251.93; ETA: 0.2 minutes
# Step 73500 of 400000; TPS: 33980.21; ETA: 0.2 minutes
# Step 84000 of 400000; TPS: 34449.74; ETA: 0.2 minutes
# Step 94500 of 400000; TPS: 34875.84; ETA: 0.1 minutes
# Step 105000 of 400000; TPS: 35176.87; ETA: 0.1 minutes
# Step 115500 of 400000; TPS: 35439.62; ETA: 0.1 minutes
# Step 126000 of 400000; TPS: 35641.47; ETA: 0.1 minutes
# Step 136500 of 400000; TPS: 35852.74; ETA: 0.1 minutes
# Step 147000 of 400000; TPS: 36037.99; ETA: 0.1 minutes
# Step 157500 of 400000; TPS: 36221.09; ETA: 0.1 minutes
# Step 168000 of 400000; TPS: 36379.67; ETA: 0.1 minutes
# Step 178500 of 400000; TPS: 36516.37; ETA: 0.1 minutes
# Step 189000 of 400000; TPS: 36695.22; ETA: 0.1 minutes
# Step 199500 of 400000; TPS: 36821.53; ETA: 0.1 minutes
# Step 210000 of 400000; TPS: 36931.78; ETA: 0.1 minutes
# Step 220500 of 400000; TPS: 36708.98; ETA: 0.1 minutes
# Step 231000 of 400000; TPS: 36680.33; ETA: 0.1 minutes
# Step 241500 of 400000; TPS: 36733.11; ETA: 0.1 minutes
# Step 252000 of 400000; TPS: 36661.93; ETA: 0.1 minutes
# Step 262500 of 400000; TPS: 36626.85; ETA: 0.1 minutes
# Step 273000 of 400000; TPS: 36601.1; ETA: 0.1 minutes
# Step 283500 of 400000; TPS: 36546.51; ETA: 0.1 minutes
# Step 294000 of 400000; TPS: 36615.27; ETA: 0.0 minutes
# Step 304500 of 400000; TPS: 36701.96; ETA: 0.0 minutes
# Step 315000 of 400000; TPS: 36761.62; ETA: 0.0 minutes
# Step 325500 of 400000; TPS: 36768.17; ETA: 0.0 minutes
# Step 336000 of 400000; TPS: 36746.37; ETA: 0.0 minutes
# Step 346500 of 400000; TPS: 36733.22; ETA: 0.0 minutes
# Step 357000 of 400000; TPS: 36730.79; ETA: 0.0 minutes
# Step 367500 of 400000; TPS: 36764.63; ETA: 0.0 minutes
# Step 378000 of 400000; TPS: 36779.95; ETA: 0.0 minutes
# Step 388500 of 400000; TPS: 36732.45; ETA: 0.0 minutes
# Step 399000 of 400000; TPS: 36669.09; ETA: 0.0 minutes
# Initializing simulation state from a gsd.hoomd.Frame.
# Step 10500 of 400000; TPS: 18405.17; ETA: 0.4 minutes
# Step 21000 of 400000; TPS: 24829.3; ETA: 0.3 minutes
# Step 31500 of 400000; TPS: 28119.8; ETA: 0.2 minutes
# Step 42000 of 400000; TPS: 30118.17; ETA: 0.2 minutes
# Step 52500 of 400000; TPS: 31426.68; ETA: 0.2 minutes
# Step 63000 of 400000; TPS: 32316.28; ETA: 0.2 minutes
# Step 73500 of 400000; TPS: 32990.59; ETA: 0.2 minutes
# Step 84000 of 400000; TPS: 33500.65; ETA: 0.2 minutes
# Step 94500 of 400000; TPS: 33960.04; ETA: 0.1 minutes
# Step 105000 of 400000; TPS: 34299.69; ETA: 0.1 minutes
# Step 115500 of 400000; TPS: 34604.71; ETA: 0.1 minutes
# Step 126000 of 400000; TPS: 34836.04; ETA: 0.1 minutes
# Step 136500 of 400000; TPS: 35057.22; ETA: 0.1 minutes
# Step 147000 of 400000; TPS: 35272.44; ETA: 0.1 minutes
# Step 157500 of 400000; TPS: 35452.44; ETA: 0.1 minutes
# Step 168000 of 400000; TPS: 35592.29; ETA: 0.1 minutes
# Step 178500 of 400000; TPS: 35758.42; ETA: 0.1 minutes
# Step 189000 of 400000; TPS: 35883.79; ETA: 0.1 minutes
# Step 199500 of 400000; TPS: 36038.09; ETA: 0.1 minutes
# Step 210000 of 400000; TPS: 36130.88; ETA: 0.1 minutes
# Step 220500 of 400000; TPS: 36198.27; ETA: 0.1 minutes
# Step 231000 of 400000; TPS: 36098.78; ETA: 0.1 minutes
# Step 241500 of 400000; TPS: 36033.75; ETA: 0.1 minutes
# Step 252000 of 400000; TPS: 36042.46; ETA: 0.1 minutes
# Step 262500 of 400000; TPS: 35979.82; ETA: 0.1 minutes
# Step 273000 of 400000; TPS: 35817.3; ETA: 0.1 minutes
# Step 283500 of 400000; TPS: 35654.16; ETA: 0.1 minutes
# Step 294000 of 400000; TPS: 35539.94; ETA: 0.0 minutes
# Step 304500 of 400000; TPS: 35576.7; ETA: 0.0 minutes
# Step 315000 of 400000; TPS: 35513.27; ETA: 0.0 minutes
# Step 325500 of 400000; TPS: 35560.75; ETA: 0.0 minutes
# Step 336000 of 400000; TPS: 35614.09; ETA: 0.0 minutes
# Step 346500 of 400000; TPS: 35670.75; ETA: 0.0 minutes
# Step 357000 of 400000; TPS: 35700.21; ETA: 0.0 minutes
# Step 367500 of 400000; TPS: 35729.24; ETA: 0.0 minutes
# Step 378000 of 400000; TPS: 35782.24; ETA: 0.0 minutes
# Step 388500 of 400000; TPS: 35832.06; ETA: 0.0 minutes
# Step 399000 of 400000; TPS: 35878.4; ETA: 0.0 minutes
